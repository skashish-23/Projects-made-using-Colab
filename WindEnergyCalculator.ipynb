# %% [markdown]
# <a href="https://colab.research.google.com/github/skashish-23/Projects-made-using-Colab/blob/main/WindEnergyCalculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Turbine specs
ROTOR_DIA = 112 #in meter, rotor diameter
ELEVATION = 2.3 #in meter, added to obtain hub height for wind energy generation calculation
RATER_POWER = 3.3e6 #in Watts
CUT_IN_SPEED = 3 #in m/s
CUT_OUT_SPEED = 25 #in m/s
AIR_DENSITY = 1.225 #in kg/m3
CP = 0.38
#REF_Height =

# %%
swept_area = (m.pi/4)*(ROTOR_DIA**2)
hub_height = (ROTOR_DIA/2)+2.3+(0.1*ROTOR_DIA)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math as m

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
columns_to_import = ['Wind Speed (avg)', 'Theoretical2 corr']  # Replace with actual column names

# Import only specific columns from Excel file into a DataFrame
df = pd.read_excel("", usecols=columns_to_import)

# %%
date_range = pd.date_range(start='2015-06-01 00:00:00', end='2024-01-25 13:30:00', freq='10T')

# Create an empty DataFrame with the datetime index
df.index= date_range

# %%
df
# Out:
#                      Wind Speed (avg)  Theoretical2 corr
# 2015-06-01 00:00:00               9.6        2050.993373
# 2015-06-01 00:10:00               9.7        2115.756875
# 2015-06-01 00:20:00              10.0        2318.198166
# 2015-06-01 00:30:00               8.5        1423.663449
# 2015-06-01 00:40:00               8.1        1231.985551
# ...                               ...                ...
# 2024-01-25 12:50:00               6.0         500.730804
# 2024-01-25 13:00:00               5.7         429.314073
# 2024-01-25 13:10:00               5.1         307.511305
# 2024-01-25 13:20:00               5.2         325.957208
# 2024-01-25 13:30:00               6.3         579.658497
#
# [455122 rows x 2 columns]

# %%
wind_power = lambda wind_velocity: CP*0.5 * AIR_DENSITY * swept_area * (wind_velocity**3)/1000 # A function to calculate the power in the wind in watts

# %%
df["power_in_wind"] = wind_power(df["Wind Speed (avg)"])

# %%
df
# Out:
#                      Wind Speed (avg)  Theoretical2 corr  power_in_wind
# 2015-06-01 00:00:00               9.6        2050.993373    2028.753656
# 2015-06-01 00:10:00               9.7        2115.756875    2092.814902
# 2015-06-01 00:20:00              10.0        2318.198166    2293.061044
# 2015-06-01 00:30:00               8.5        1423.663449    1408.226114
# 2015-06-01 00:40:00               8.1        1231.985551    1218.626654
# ...                               ...                ...            ...
# 2024-01-25 12:50:00               6.0         500.730804     495.301186
# 2024-01-25 13:00:00               5.7         429.314073     424.658854
# 2024-01-25 13:10:00               5.1         307.511305     304.176841
# 2024-01-25 13:20:00               5.2         325.957208     322.422727
# 2024-01-25 13:30:00               6.3         579.658497     573.373035
#
# [455122 rows x 3 columns]

# %%
df['Difference'] = df['power_in_wind'] - df['Theoretical2 corr']
df
# Out:
#                      Wind Speed (avg)  Theoretical2 corr  power_in_wind  \
# 2015-06-01 00:00:00               9.6        2050.993373    2028.753656
# 2015-06-01 00:10:00               9.7        2115.756875    2092.814902
# 2015-06-01 00:20:00              10.0        2318.198166    2293.061044
# 2015-06-01 00:30:00               8.5        1423.663449    1408.226114
# 2015-06-01 00:40:00               8.1        1231.985551    1218.626654
# ...                               ...                ...            ...
# 2024-01-25 12:50:00               6.0         500.730804     495.301186
# 2024-01-25 13:00:00               5.7         429.314073     424.658854
# 2024-01-25 13:10:00               5.1         307.511305     304.176841
# 2024-01-25 13:20:00               5.2         325.957208     322.422727
# 2024-01-25 13:30:00               6.3         579.658497     573.373035
#
#                      Difference
# 2015-06-01 00:00:00  -22.239716
# 2015-06-01 00:10:00  -22.941972
# ...

# %%
df['Percentage Error'] = abs((df['Difference']) / df['Theoretical2 corr']) * 100
df
# Out:
#                      Wind Speed (avg)  Theoretical2 corr  power_in_wind  \
# 2015-06-01 00:00:00               9.6        2050.993373    2028.753656
# 2015-06-01 00:10:00               9.7        2115.756875    2092.814902
# 2015-06-01 00:20:00              10.0        2318.198166    2293.061044
# 2015-06-01 00:30:00               8.5        1423.663449    1408.226114
# 2015-06-01 00:40:00               8.1        1231.985551    1218.626654
# ...                               ...                ...            ...
# 2024-01-25 12:50:00               6.0         500.730804     495.301186
# 2024-01-25 13:00:00               5.7         429.314073     424.658854
# 2024-01-25 13:10:00               5.1         307.511305     304.176841
# 2024-01-25 13:20:00               5.2         325.957208     322.422727
# 2024-01-25 13:30:00               6.3         579.658497     573.373035
#
#                      Difference  Percentage Error
# 2015-06-01 00:00:00  -22.239716          1.084339
# ...
